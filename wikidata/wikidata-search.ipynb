# %%
import pandas
import functools
import json
import numpy
import os
from bs4 import BeautifulSoup

# %%
import requests

# %%
version_codes = pandas.read_csv('versions_with_langcodes.csv')

# %%
version_codes
# Out:
#       version_id language                                       version_name  \
# 0              1      eng                          american standard version
# 1              2      eng                                    amplified bible
# 2              3      eng                    amplified bible classic edition
# 3              4      eng                     catholic public domain version
# 4              5      eng                           christian standard bible
# ...          ...      ...                                                ...
# 2157        2353   zho_tw  %E8%95%AD%E9%90%B5%E7%AC%9B%E6%96%B0%E8%AD%AF%...
# 2158        2354   zho_tw  %E8%95%AD%E9%9D%9C%E5%B1%B1%E6%96%B0%E7%B6%93%...
# 2159        2355   zho_tw  %E9%99%B8%E4%BA%A8%E7%90%86%E9%84%AD%E5%A3%BD%...
# 2160        2357      kor                                                NaN
# 2161        2335      zho  %E7%A5%9E %E6%96%B0%E6%A0%87%E7%82%B9%E5%92%8C...
#
#                            wikidata_entity
# 0     http://www.wikidata.org/entity/Q1860
# 1     http://www.wikidata.org/entity/Q1860
# 2     http://www.wikidata.org/entity/Q1860
# 3     http://www.wikidata.org/entity/Q1860
# 4     http://www.wikidata.org/entity/Q1860
# ...                                    ...
# 2157                                   NaN
# 2158                                   NaN
# 2159                                   NaN
# 2160  http://www.wikidata.org/entity/Q9176
# 2161  http://www.wikidata.org/entity/Q7850
#
# [2162 rows x 4 columns]

# %%
version_codes.language.nunique()
# Out:
# 1504

# %%
version_codes.wikidata_entity.nunique()
# Out:
# 1500

# %%
version_codes.wikidata_entity.iloc[0]
# Out:
# 'http://www.wikidata.org/entity/Q1860'

# %%
def get_entity_from_url(url):
    if type(url) == type(''):
        return url.split('/')[-1]
    else:
        return numpy.nan
    
version_codes['entity'] = version_codes.wikidata_entity.map(get_entity_from_url)
version_codes
# Out:
#       version_id language                                       version_name  \
# 0              1      eng                          american standard version
# 1              2      eng                                    amplified bible
# 2              3      eng                    amplified bible classic edition
# 3              4      eng                     catholic public domain version
# 4              5      eng                           christian standard bible
# ...          ...      ...                                                ...
# 2157        2353   zho_tw  %E8%95%AD%E9%90%B5%E7%AC%9B%E6%96%B0%E8%AD%AF%...
# 2158        2354   zho_tw  %E8%95%AD%E9%9D%9C%E5%B1%B1%E6%96%B0%E7%B6%93%...
# 2159        2355   zho_tw  %E9%99%B8%E4%BA%A8%E7%90%86%E9%84%AD%E5%A3%BD%...
# 2160        2357      kor                                                NaN
# 2161        2335      zho  %E7%A5%9E %E6%96%B0%E6%A0%87%E7%82%B9%E5%92%8C...
#
#                            wikidata_entity entity
# 0     http://www.wikidata.org/entity/Q1860  Q1860
# 1     http://www.wikidata.org/entity/Q1860  Q1860
# 2     http://www.wikidata.org/entity/Q1860  Q1860
# 3     http://www.wikidata.org/entity/Q1860  Q1860
# 4     http://www.wikidata.org/entity/Q1860  Q1860
# ...                                    ...    ...
# 2157                                   NaN    NaN
# 2158                                   NaN    NaN
# 2159                                   NaN    NaN
# 2160  http://www.wikidata.org/entity/Q9176  Q9176
# 2161  http://www.wikidata.org/entity/Q7850  Q7850
#
# [2162 rows x 5 columns]

# %%
#@functools.lru_cache(2)
def get_url_content(entity):
    local_cache = f'.cache/{entity}.json'
    if os.path.exists(local_cache):
        with open(local_cache) as f:
            return json.load(f)
    url = 'http://www.wikidata.org/entity/' + entity + '.json'
    print(f"Fetching {url}")
    r = requests.get(url)
    answer = r.json()
    os.makedirs('.cache', exist_ok=True)
    with open(local_cache, 'w') as f:
        json.dump(answer, f, indent=4)
    return answer

# %%
@functools.lru_cache(5000)
def get_label(entity):
    if type(entity) != type(''):
        return numpy.nan
    obj = get_url_content(entity)
    this_entity = obj['entities'][entity]
    labels = this_entity['labels']
    if 'en' in labels:
        return labels['en']['value']
    raise IndexError(entity)

# %%
@functools.lru_cache(5000)
def get_property_label(property):
    """Any better way of doing this?"""
    url = f'http://www.wikidata.org/wiki/Property:{property}' 
    r = requests.get(url)
    soup = BeautifulSoup(r.text)
    title = soup.find('span', class_='wikibase-title-label')
    return title.string

# %%
version_codes['language_name_in_english'] = version_codes.entity.map(get_label)

# %%
@functools.lru_cache(100000)
def get_claim_list(entity, claim):
    if type(entity) != type(''):
        return numpy.nan
    obj = get_url_content(entity)
    claims = obj['entities'][entity]['claims']
    if claim in claims:
        return [x['mainsnak'].get('datavalue') for x in claims[claim]]
    else:
        return []

# %%
def instance_of(entity):
    if type(entity) != type(''):
        return numpy.nan
    raw_content = get_claim_list(entity, 'P31')
    answer = []
    for v in raw_content:
        name = get_label(v['value']['id'])
        answer.append(name)
    return answer

# %%
version_codes['instance_of'] = version_codes.entity.map(instance_of)

# %%
def country(entity):
    if type(entity) != type(''):
        return numpy.nan
    raw_content = get_claim_list(entity, 'P17')
    answer = []
    for v in raw_content:
        name = get_label(v['value']['id'])
        answer.append(name)
    return answer

# %%
version_codes['country'] = version_codes.entity.map(country)

# %%
def claims(entity):
    if type(entity) != type(''):
        return []
    obj = get_url_content(entity)
    claims = obj['entities'][entity]['claims']
    return list(claims.keys())

# %%
known_claims = set()
for entity in version_codes.entity:
    known_claims.update(claims(entity))
known_claims
# Out:
# {'P10',
#  'P1014',
#  'P1018',
#  'P1036',
#  'P1051',
#  'P1098',
#  'P1151',
#  'P1190',
#  'P1225',
#  'P1232',
#  'P1245',
#  'P1249',
#  'P1251',
#  'P1252',
#  'P1256',
#  'P126',
#  'P127',
#  'P1282',
#  'P1296',
#  'P131',
#  'P1343',
#  'P135',
#  'P1365',
#  'P1366',
#  'P1368',
#  'P1376',
#  'P138',
#  'P1394',
#  'P1396',
#  'P1417',
#  'P1424',
#  'P144',
#  'P1448',
#  'P1466',
#  'P1482',
#  'P1535',
#  'P155',
#  'P1552',
#  'P156',
#  'P158',
#  'P1613',
#  'P1617',
#  'P1627',
#  'P163',
#  'P1687',
#  'P17',
#  'P170',
#  'P1705',
#  'P1711',
#  'P172',
#  'P1798',
#  'P18',
#  'P1807',
#  'P1813',
#  'P1842',
#  'P1846',
#  'P186',
#  'P1889',
#  'P190',
#  'P1999',
#  'P2161',
#  'P2163',
#  'P218',
#  'P2184',
#  'P219',
#  'P2192',
#  'P220',
#  'P221',
#  'P2263',
#  'P227',
#  'P2283',
#  'P2341',
#  'P2347',
#  'P2355',
#  'P242',
#  'P244',
#  'P2572',
#  'P2579',
#  'P2581',
#  'P2587',
#  'P2588',
#  'P2590',
#  'P2596',
#  'P2671',
#  'P268',
#  'P269',
#  'P276',
#  'P278',
#  'P279',
#  'P282',
#  'P2888',
#  'P2910',
#  'P2919',
#  'P2924',
#  'P2959',
#  'P2989',
#  'P3021',
#  'P305',
#  'P3095',
#  'P3097',
#  'P31',
#  'P3103',
#  'P3161',
#  'P3219',
#  'P3221',
#  'P3222',
#  'P3365',
#  'P3381',
#  'P3417',
#  'P349',
#  'P3553',
#  'P3569',
#  'P361',
#  'P366',
#  'P37',
#  'P3719',
#  'P373',
#  'P3823',
#  'P3847',
#  'P3916',
#  'P3964',
#  'P3969',
#  'P3984',
#  'P407',
#  'P41',
#  'P4132',
#  'P4210',
#  'P4211',
#  'P4212',
#  'P424',
#  'P4254',
#  'P4342',
#  'P443',
#  'P4527',
#  'P457',
#  'P460',
#  'P461',
#  'P4613',
#  'P463',
#  'P4644',
#  'P4801',
#  'P4839',
#  'P4913',
#  'P495',
#  'P5008',
#  'P5019',
#  'P508',
#  'P51',
#  'P5109',
#  'P5110',
#  'P5125',
#  'P5160',
#  'P5184',
#  'P5198',
#  'P5206',
#  'P5250',
#  'P527',
#  'P5337',
#  'P571',
#  'P5737',
#  'P5748',
#  'P580',
#  'P5913',
#  'P5922',
#  'P5996',
#  'P6081',
#  'P61',
#  'P6104',
#  'P6106',
#  'P625',
#  'P6262',
#  'P629',
#  'P6293',
#  'P6366',
#  'P6385',
#  'P6404',
#  'P646',
#  'P6520',
#  'P6541',
#  'P6573',
#  'P6706',
#  'P6723',
#  'P6839',
#  'P6870',
#  'P6900',
#  'P691',
#  'P6915',
#  'P7033',
#  'P7084',
#  'P7157',
#  'P7293',
#  'P7305',
#  'P7314',
#  'P737',
#  'P740',
#  'P747',
#  'P7502',
#  'P7506',
#  'P7666',
#  'P78',
#  'P7818',
#  'P7822',
#  'P7827',
#  'P7829',
#  'P7832',
#  'P7867',
#  'P7884',
#  'P793',
#  'P7959',
#  'P7982',
#  'P8168',
#  'P8248',
#  'P8309',
#  'P8349',
#  'P8370',
#  'P8408',
#  'P8472',
#  'P85',
#  'P8519',
#  'P8529',
#  'P8539',
#  'P856',
#  'P8647',
#  'P8786',
#  'P8799',
#  'P8885',
#  'P898',
#  'P9013',
#  'P902',
#  'P9060',
#  'P9070',
#  'P910',
#  'P9100',
#  'P9123',
#  'P92',
#  'P920',
#  'P9291',
#  'P9318',
#  'P9322',
#  'P935',
#  'P948',
#  'P949',
#  'P9498',
#  'P950',
#  'P9545',
#  'P9717',
#  'P972',
#  'P973',
#  'P9748',
#  'P9753',
#  'P989',
#  'P996',
#  'P998'}

# %%
len(known_claims)
# Out:
# 253

# %%
get_property_label('P1014')
# Out:
# 'Art & Architecture Thesaurus ID'

# %%
for claim in known_claims:
    print(claim, get_property_label(claim))
# Out:
# P948 page banner
# P8370 UNBIS Thesaurus ID
# P2283 uses
# P4342 Store norske leksikon ID
# P7293 PLWABN ID
# P4211 Bashkir encyclopedia (Russian version) ID
# P1098 number of speakers
# P7867 category for maps
# P5337 Google News topics ID
# P6541 Stack Exchange site
# P7157 The Top Tens ID
# P2579 studied by
# P920 LEM ID
# P6404 Treccani's Dizionario di Storia ID
# P4254 Bengali Banglapedia ID
# P1368 LNB ID
# P1256 Iconclass notation
# P138 named after
# P1366 replaced by
# P3984 subreddit
# P691 NKCR AUT ID
# P3161 has grammatical mood
# P3553 Zhihu topic ID
# P5922 ANZSRC 2008 FoR ID
# P7832 Basque Vikidia ID
# P950 Biblioteca Nacional de España ID
# P1617 BBC Things ID
# P1014 Art & Architecture Thesaurus ID
# P7084 related category
# P457 foundational text
# P18 image
# P7959 historic county
# P163 flag
# P127 owned by
# P2163 FAST ID
# P131 located in the administrative territorial entity
# P172 ethnic group
# P279 subclass of
# P461 opposite of
# P269 IdRef ID
# P1687 Wikidata property
# P1051 PSH ID
# P2192 endangeredlanguages.com ID
# P6081 RIA Novosti reference
# P85 anthem
# P8647 Library of Congress Children's Subject Headings ID
# P4613 Encyclopedia of Modern Ukraine ID
# P1394 Glottolog code
# P7822 Italian Vikidia ID
# P5125 Wikimedia outline
# P349 National Diet Library ID
# P3222 NE.se ID
# P6870 Latvian National Encyclopedia Online ID
# P972 catalog
# P460 said to be the same as
# P3221 New York Times topic ID
# P221 ISO 639-6 code
# P9100 GitHub topic
# P8885 Namuwiki ID
# P9318 Ávvir topic ID
# P9013 Encyclopedia of Saami Culture ID
# P5109 has grammatical gender
# P6262 Fandom article ID
# P2596 culture
# P3365 Treccani ID
# P625 coordinate location
# P4913 dialect of
# P3964 BDCYL authority ID
# P6104 maintained by WikiProject
# P8786 dedicated heritage entity
# P527 has part
# P7506 Naver Encyclopedia ID
# P8309 Yle topic ID
# P6366 Microsoft Academic ID
# P2355 UNESCO Atlas of the World's Languages in Danger ID
# P92 main regulatory text
# P1448 official name
# P1798 ISO 639-5 code
# P282 writing system
# P305 IETF language tag
# P190 twinned administrative body
# P5019 Brockhaus Enzyklopädie online ID
# P996 document file on Wikimedia Commons
# P220 ISO 639-3 code
# P7982 Hrvatska enciklopedija ID
# P8519 RKD thesaurus ID
# P1424 topic's main template
# P2919 label in sign language
# P902 HDS ID
# P37 official language
# P5748 Basisklassifikation
# P9545 Encyclopedia of China Online Database ID
# P6915 Gambay ID
# P1282 OpenStreetMap tag or key
# P156 followed by
# P7033 Australian Educational Vocabulary ID
# P5737 Chinese Moegirlpedia ID
# P9060 POSIX locale identifier
# P3103 has tense
# P1889 different from
# P8408 KBpedia ID
# P1151 topic's main Wikimedia portal
# P1249 time of earliest written record
# P5184 Daum Encyclopedia ID
# P629 edition or translation of
# P1842 Global Anabaptist Mennonite Encyclopedia Online ID
# P7502 Golden ID
# P4527 UK Parliament thesaurus ID
# P910 topic's main category
# P61 discoverer or inventor
# P5008 on focus list of Wikimedia project
# P1535 used by
# P8168 FactGrid item ID
# P1613 IRC channel
# P2572 hashtag
# P9322 SVKKL authority ID
# P31 instance of
# P2590 BPS language code
# P6723 BlackPast.org ID
# P424 Wikimedia language code
# P2989 has grammatical case
# P1251 ABS ASCL 2011 code
# P7827 Spanish Vikidia ID
# P6520 Lokalhistoriewiki.no ID
# P2161 Guthrie code
# P7818 French Vikidia ID
# P571 inception
# P4210 Bashkir encyclopedia (Bashkir version) ID
# P443 pronunciation audio
# P17 country
# P1417 Encyclopædia Britannica Online ID
# P8472 Encyclopedie berbere keyword ID
# P1846 distribution map
# P155 follows
# P278 GOST 7.75–97 code
# P3969 signed form
# P5250 IAB code
# P51 audio
# P9123 Catalan Vikidia ID
# P7829 English Vikidia ID
# P9748 Wikimedia Incubator URL
# P935 Commons gallery
# P463 member of
# P1813 short name
# P2588 administrative code of Indonesia
# P7305 Online PWN Encyclopedia ID
# P898 IPA transcription
# P276 location
# P737 influenced by
# P366 use
# P144 based on
# P6900 NicoNicoPedia ID
# P1252 AUSTLANG code
# P747 has edition or translation
# P1036 Dewey Decimal Classification
# P8248 Colon Classification
# P1190 Universal Decimal Classification
# P9070 Internet Encyclopedia of Ukraine ID
# P135 movement
# P158 seal image
# P508 BNCF Thesaurus ID
# P3021 Iranica ID
# P268 Bibliothèque nationale de France ID
# P170 creator
# P3719 regulated by
# P2924 Great Russian Encyclopedia Online ID
# P3097 ISBN identifier group
# P2347 YSO ID
# P4132 linguistic typology
# P8349 Proleksis enciklopedija ID
# P856 official website
# P3569 Cultureel Woordenboek ID
# P1711 British Museum person or institution ID
# P1705 native label
# P78 top-level Internet domain
# P2184 history of topic
# P9753 Wikidata language code
# P10 video
# P6573 Klexikon article ID
# P4801 LoC and MARC vocabularies ID
# P495 country of origin
# P1482 Stack Exchange tag
# P407 language of work or name
# P219 ISO 639-2 code
# P1018 language regulatory body
# P2888 exact match
# P989 spoken text audio
# P6385 Krugosvet article
# P1552 has quality
# P126 maintained by
# P2959 permanent duplicated item
# P5160 Thesaurus for Graphic Materials ID
# P2581 BabelNet ID
# P3847 Open Library subject ID
# P8529 ANZSRC 2020 FoR ID
# P7314 TDV İslam Ansiklopedisi ID
# P3381 File Format Wiki page ID
# P8799 Twitch tag ID
# P186 made from material
# P6706 De Agostini ID
# P5198 ASC Leiden Thesaurus ID
# P3417 Quora topic ID
# P9717 Native Land language ID
# P227 GND ID
# P973 described at URL
# P1225 U.S. National Archives Identifier
# P2671 Google Knowledge Graph ID
# P793 significant event
# P5110 has grammatical person
# P7884 Joconde inscription ID
# P646 Freebase ID
# P7666 Visuotinė lietuvių enciklopedija ID
# P6839 TV Tropes identifier
# P4839 Wolfram Language entity code
# P1396 Linguasphere code
# P4212 PACTOLS thesaurus ID
# P6293 YSA ID
# P242 locator map image
# P2587 has phoneme
# P949 National Library of Israel ID
# P3219 Encyclopædia Universalis ID
# P6106 uses capitalization for
# P740 location of formation
# P5996 category for films in this language
# P5206 has conjugation class
# P1365 replaces
# P1999 UNESCO language status
# P1807 Great Aragonese Encyclopedia ID
# P244 Library of Congress authority ID
# P2910 icon
# P8539 ERIC Thesaurus ID
# P1296 Gran Enciclopèdia Catalana ID
# P1466 WALS lect code
# P4644 ESCO skill ID
# P3095 practiced by
# P998 Curlie ID
# P1343 described by source
# P580 start time
# P2341 indigenous to
# P1627 Ethnologue.com language code
# P5913 has inflection class
# P3823 Ethnologue language status
# P1376 capital of
# P373 Commons category
# P2263 ISOCAT id
# P9498 Enzyklopädie des europäischen Ostens ID
# P361 part of
# P3916 UNESCO Thesaurus ID
# P41 flag image
# P9291 Eesti entsüklopeedia ID
# P218 ISO 639-1 code
# P1232 Linguist list code
# P1245 OmegaWiki Defined Meaning

# %%
useful_and_interesting_claims = [ 'P5913', 'P2192', 'P1365',
                                 #'P527', 
                                 'P2341', 'P3823', 'P5206', 
                                 #'P2587',
                                 'P2989', 'P279',
'P5110', 'P3103', 'P461', 'P4913', 'P1466',  'P366', 
'P282', 'P5109', 'P460', #'P495', 
                                 'P4132',  'P2283', 
                                 #'P8786',
'P3161', 'P1098', 'P1535', 'P126', 'P1249', 'P144',
'P737']

# %%
def coordinates(claim_list):
    if type(claim_list) != type([]):
        return []
    return [(x['value']['latitude'], x['value']['longitude']) for x in claim_list]
locations_records = []
for entity in version_codes.entity.unique():
    if type(entity) == float:
        continue
    for lat,long in coordinates(get_claim_list(entity, 'P625')):
        locations_records.append({'entity': entity, 'latitude': lat, 'longitude': long })
    for country_id in get_claim_list(entity, 'P17'):
        locations_records.append({'entity': entity, 'country': get_label(country_id['value']['id'])})
    for country_id in get_claim_list(entity, 'P495'):
        locations_records.append({'entity': entity, 'country': get_label(country_id['value']['id'])})
    for location in get_claim_list(entity, "P276"):
        location_entity = location['value']['id']
        location_label = get_label(location_entity)
        countries = get_claim_list(location_entity, 'P17')
        if countries == []:
            locations_records.append({'entity': entity, 'location_entity': location_entity,
                                      'location_name': location_label})
        else:
            for country in countries:
                locations_records.append({'entity': entity, 'location_entity': location_entity,
                                      'location_name': location_label,
                                         'country': get_label(country['value']['id'])})
    for home in get_claim_list(entity, "P2341"):
        home_entity = home['value']['id']
        home_name = get_label(home_entity)
        countries = get_claim_list(home_entity, "P17")
        if countries == []:
            locations_records.append({'entity': entity, 'indigenous_to_name': 
                                      home_name, 'indigenous_to_entity': home_entity})
        else:
            for country in countries:
                locations_records.append({'entity': entity, 
                                          'indigenous_to_name': 
                                      home_name, 
                                          'indigenous_to_entity': home_entity, 
                                          'country': get_label(country['value']['id'])})
locations_df = pandas.DataFrame.from_records(locations_records)
locations_df.to_csv('geomap.csv', index=False)

# %%
locations_df[locations_df.location_entity.notnull() & locations_df.country.isnull()]
# Out:
#         entity country indigenous_to_name indigenous_to_entity  latitude  \
# 1972  Q3094570     NaN                NaN                  NaN       NaN
# 1973  Q3094570     NaN                NaN                  NaN       NaN
# 1974  Q3094570     NaN                NaN                  NaN       NaN
# 1975  Q3094570     NaN                NaN                  NaN       NaN
# 1976  Q3094570     NaN                NaN                  NaN       NaN
# 1977  Q3094570     NaN                NaN                  NaN       NaN
# 6263  Q1142333     NaN                NaN                  NaN       NaN
#
#       longitude location_entity location_name
# 1972        NaN       Q24287192     Wangeotek
# 1973        NaN       Q24287209           Kao
# 1974        NaN       Q24287218          Kira
# 1975        NaN       Q24287221          Kedi
# 1976        NaN       Q24287223    Laba Besar
# 1977        NaN       Q24287227          Goal
# 6263        NaN       Q24287148          Pale

# %%
locations_df[locations_df.country.map(lambda x: type(x) == type('') and '+' in x)]
# Out:
# Empty DataFrame
# Columns: [entity, country, indigenous_to_name, indigenous_to_entity, latitude, longitude, location_entity, location_name]
# Index: []

# %%
languages_with_countries = locations_df[locations_df.country.notnull()].groupby('entity').country.nunique().index

# %%
locations_df.country.nunique()
# Out:
# 298

# %%
locations_df[locations_df.country.notnull()].groupby('entity').country.unique()
# Out:
# entity
# Q10179                     [Lesotho, Mozambique, South Africa]
# Q10266010                                             [Brazil]
# Q10322066                                             [Brazil]
# Q10510745                                          [Australia]
# Q1066766     [Tajikistan, Turkmenistan, Uzbekistan, Soviet ...
#                                    ...
# Q948514                                       [Colombia, Peru]
# Q952133                                     [Papua New Guinea]
# Q957945                                              [Vanuatu]
# Q9610                        [Bangladesh, India, Sierra Leone]
# Q962392                                     [Brazil, Colombia]
# Name: country, Length: 1485, dtype: object

# %%
lookup_country_of_language = locations_df[locations_df.country.notnull()].groupby('entity').country.unique().to_dict()
version_codes['country'] = version_codes.entity.map(lookup_country_of_language)

# %%
version_codes.sample(50, random_state=19721812)
# Out:
#       version_id language                                       version_name  \
# 700          777      ilo                   ti baro a naimbag a damag biblia
# 1386        1508      ktj                                   nysa a haantitie
# 188          210      bdh                       mkanda lor b lomo k dos ey e
# 929         1015      kru                                             nt bsi
# 1533        1676      san                  sanskrit bible nt in oriya script
# 389          428      dga                                naamen npaalaa gane
# 1569        1716      shp                   diossen joi jatixonbi onanti joi
# 2086        2278      tel                                           irv 2019
# 1043        1136      mgh                                makua new testament
# 1724        1891      tob                          nuevo testamento toba sur
# 928         1013      kmr                                             ngl rz
# 1331        1451      ndo                               ombiimbeli ondjapuki
# 739          815      mxt              tuhun cha sanaha ra jesucristo chi yo
# 1357        1478      pnb                         ngb no aad nm nthrthn shd
# 407          449      ded                                  deduamiti kibi 40
# 2108        2301  mya_zaw                     judson bible in zawgyi version
# 833          913      naq                                            elobmis
# 861          941      rim                               kirimi new testament
# 868          948      swh                                biblia habari njema
# 840          921      heh                                    lufingano lupya
# 495          546      spa                      traduccion en lenguaje actual
# 796          870      gam                            jisas kandjiyebe wopake
# 78            84      ady                                 kebaryshur indzhyl
# 810          889      xsm                                    xsm w tn d kasm
# 2049        2239      ckb                               mn no o zboorn b srn
# 793          867      xla                                           kadle yu
# 1112        1213      mee                              piunga ba bonga a pau
# 172          193      bvd                 na alangaia falu ana baea i baeguu
# 971         1059      lww                    lologena wo kienane yesu kristo
# 1372        1493      mil                  tnuhu ni caha y ndixi xito cuu uu
# 1318        1437      zac                         dizaque shte dios con dize
# 1738        1906      ven                   bivhili khethwa mafhungo madifha
# 369          403      crn  niuucari t jejcua t ajta jmeen raaxa ajna tava...
# 1117        1219      zam   testament cub co nac dis ndac chen tad jesucrist
# 209          233      byr                              gotyare yagaala mudke
# 86            94      agr  awajun apajui chichame pegkejam porciones del ...
# 1785        1955      gdn                                          iya yonai
# 164          184      ayr                                  qullan arunaka dc
# 1488        1630      ndi                           samba leko new testament
# 1711        1878      thk                                kiriikaniro kiiyeru
# 1933        2116      ssw                                 siswati 1996 bible
# 503          554      ots  el nuevo testamento en otomi de san felipe san...
# 1155        1260      ign     taurinakene maechejiriruwai ema viya tikaijare
# 914          997      kue                                   yesus kamo wakai
# 1684        1848      tav                            new testament in tatuyo
# 1181        1288      yua                                        biblia maya
# 437          484      quz                           quechua cuzco bible 1988
# 2156        2352   zho_tw  %E8%81%96%E7%B6%93%E7%95%B6%E4%BB%A3%E8%AD%AF%...
# 399          441      aso                                 mono godolo gosoho
# 1962        2141      grc          patriarxiko keimeno ekdosh antwniadh 1904
#
#                                wikidata_entity     entity  \
# 700      http://www.wikidata.org/entity/Q35936     Q35936
# 1386  http://www.wikidata.org/entity/Q10975356  Q10975356
# 188    http://www.wikidata.org/entity/Q2880165   Q2880165
# 929      http://www.wikidata.org/entity/Q33492     Q33492
# 1533     http://www.wikidata.org/entity/Q11059     Q11059
# 389      http://www.wikidata.org/entity/Q35159     Q35159
# 1569   http://www.wikidata.org/entity/Q2671988   Q2671988
# 2086      http://www.wikidata.org/entity/Q8097      Q8097
# 1043     http://www.wikidata.org/entity/Q33604     Q33604
# 1724   http://www.wikidata.org/entity/Q3113756   Q3113756
# 928      http://www.wikidata.org/entity/Q36163     Q36163
# 1331     http://www.wikidata.org/entity/Q33900     Q33900
# 739   http://www.wikidata.org/entity/Q12953730  Q12953730
# 1357   http://www.wikidata.org/entity/Q1389492   Q1389492
# 407    http://www.wikidata.org/entity/Q5249850   Q5249850
# 2108                                       NaN        NaN
# 833      http://www.wikidata.org/entity/Q13301     Q13301
# 861    http://www.wikidata.org/entity/Q7193418   Q7193418
# 868    http://www.wikidata.org/entity/Q3197533   Q3197533
# 840    http://www.wikidata.org/entity/Q3129390   Q3129390
# 495       http://www.wikidata.org/entity/Q1321      Q1321
# 796    http://www.wikidata.org/entity/Q6361369   Q6361369
# 78       http://www.wikidata.org/entity/Q27776     Q27776
# 810      http://www.wikidata.org/entity/Q35552     Q35552
# 2049     http://www.wikidata.org/entity/Q36811     Q36811
# 793   http://www.wikidata.org/entity/Q10957277  Q10957277
# 1112   http://www.wikidata.org/entity/Q3305831   Q3305831
# 172    http://www.wikidata.org/entity/Q2878850   Q2878850
# 971    http://www.wikidata.org/entity/Q3237321   Q3237321
# 1372  http://www.wikidata.org/entity/Q42411307  Q42411307
# 1318   http://www.wikidata.org/entity/Q7076643   Q7076643
# 1738     http://www.wikidata.org/entity/Q32704     Q32704
# 369   http://www.wikidata.org/entity/Q12953454  Q12953454
# 1117  http://www.wikidata.org/entity/Q13541830  Q13541830
# 209    http://www.wikidata.org/entity/Q3450812   Q3450812
# 86     http://www.wikidata.org/entity/Q1526530   Q1526530
# 1785   http://www.wikidata.org/entity/Q7881084   Q7881084
# 164   http://www.wikidata.org/entity/Q20526610  Q20526610
# 1488     http://www.wikidata.org/entity/Q36381     Q36381
# 1711  http://www.wikidata.org/entity/Q15407179  Q15407179
# 1933     http://www.wikidata.org/entity/Q34014     Q34014
# 503    http://www.wikidata.org/entity/Q7413841   Q7413841
# 1155   http://www.wikidata.org/entity/Q3148190   Q3148190
# 914     http://www.wikidata.org/entity/Q137525    Q137525
# 1684   http://www.wikidata.org/entity/Q2524007   Q2524007
# 1181     http://www.wikidata.org/entity/Q13354     Q13354
# 437      http://www.wikidata.org/entity/Q35147     Q35147
# 2156                                       NaN        NaN
# 399    http://www.wikidata.org/entity/Q5220979   Q5220979
# 1962     http://www.wikidata.org/entity/Q35497     Q35497
#
#      language_name_in_english  \
# 700                   Ilocano
# 1386             Plapo Krumen
# 188                      Baka
# 929                    Kurukh
# 1533                 Sanskrit
# 389                   Dagaare
# 1569           Shipibo-Conibo
# 2086                   Telugu
# 1043           Makhuwa-Meetto
# 1724                 Toba Qom
# 928                  Kurmanji
# 1331                   Ndonga
# 739         Jamiltepec Mixtec
# 1357          Western Punjabi
# 407                     Dedua
# 2108                      NaN
# 833                  Khoekhoe
# 861                      Turu
# 868                   Swahili
# 840                      Hehe
# 495                   Spanish
# 796                   Kandawo
# 78                     Adyghe
# 810                     Kasem
# 2049                   Sorani
# 793                    Kamula
# 1112                   Mengen
# 172                    Baeggu
# 971                      Lewo
# 1372           Peñoles Mixtec
# 1318          Ocotlán Zapotec
# 1738                    Venda
# 369             El Nayar Cora
# 1117       Miahuatlán Zapotec
# 209                     Yipma
# 86                   Aguaruna
# 1785               Umanakaina
# 164            Central Aymara
# 1488              Chamba Leko
# 1711                  Tharaka
# 1933                    Swazi
# 503          San Felipe Otomi
# 1155                Ignaciano
# 914                     Kuman
# 1684                   Tatuyo
# 1181             Yucatec Maya
# 437             Cusco Quechua
# 2156                      NaN
# 399                      Dano
# 1962            Ancient Greek
#
#                                             instance_of  \
# 700                         [language, modern language]
# 1386                        [language, modern language]
# 188                         [language, modern language]
# 929                         [language, modern language]
# 1533                       [language, ancient language]
# 389                         [language, modern language]
# 1569                        [language, modern language]
# 2086                        [language, modern language]
# 1043               [dialect, language, modern language]
# 1724  [language, modern language, definitely endange...
# 928                         [language, modern language]
# 1331                        [language, modern language]
# 739                         [language, modern language]
# 1357               [dialect, language, modern language]
# 407                         [language, modern language]
# 2108                                                NaN
# 833   [language, dead language, modern language, ext...
# 861                         [language, modern language]
# 868                [dialect, language, modern language]
# 840                                   [modern language]
# 495       [natural language, language, modern language]
# 796                         [language, modern language]
# 78     [language, modern language, vulnerable language]
# 810                         [language, modern language]
# 2049                        [language, modern language]
# 793                         [language, modern language]
# 1112                        [language, modern language]
# 172                         [language, modern language]
# 971                         [language, modern language]
# 1372                        [language, modern language]
# 1318                        [language, modern language]
# 1738                        [language, modern language]
# 369                [dialect, language, modern language]
# 1117                        [language, modern language]
# 209                         [language, modern language]
# 86     [language, modern language, vulnerable language]
# 1785                        [language, modern language]
# 164                         [language, modern language]
# 1488                        [language, modern language]
# 1711                        [language, modern language]
# 1933                        [language, modern language]
# 503                         [language, modern language]
# 1155                        [language, modern language]
# 914                         [language, modern language]
# 1684  [language, modern language, definitely endange...
# 1181  [language, modern language, definitely endange...
# 437    [language, modern language, vulnerable language]
# 2156                                                NaN
# 399                         [language, modern language]
# 1962                    [language, historical language]
#
#                                                 country
# 700                                       [Philippines]
# 1386                                      [Ivory Coast]
# 188     [Democratic Republic of the Congo, South Sudan]
# 929                                 [Bangladesh, India]
# 1533  [India, British India, Mughal Empire, Sur Empi...
# 389                               [Burkina Faso, Ghana]
# 1569                                             [Peru]
# 2086                                            [India]
# 1043                             [Mozambique, Tanzania]
# 1724                              [Argentina, Paraguay]
# 928   [Armenia, Azerbaijan, Iran, Iraq, Syria, Turke...
# 1331                                          [Namibia]
# 739                                            [Mexico]
# 1357  [India, Pakistan, British India, Mughal Empire...
# 407                                  [Papua New Guinea]
# 2108                                                NaN
# 833                   [South Africa, Namibia, Botswana]
# 861                                          [Tanzania]
# 868   [Burundi, Kenya, Mozambique, Somalia, Tanzania...
# 840                                          [Tanzania]
# 495   [Spain, Andorra, Argentina, Belize, Bolivia, C...
# 796                                  [Papua New Guinea]
# 78        [Russia, Turkey, Jordan, Syria, Soviet Union]
# 810                               [Burkina Faso, Ghana]
# 2049  [Iran, Iraq, Turkey, Syria, Germany, Afghanist...
# 793                                  [Papua New Guinea]
# 1112                                 [Papua New Guinea]
# 172                                   [Solomon Islands]
# 971                                           [Vanuatu]
# 1372                                           [Mexico]
# 1318                                           [Mexico]
# 1738                           [South Africa, Zimbabwe]
# 369                                            [Mexico]
# 1117                                           [Mexico]
# 209                                  [Papua New Guinea]
# 86                                               [Peru]
# 1785                                 [Papua New Guinea]
# 164                              [Bolivia, Chile, Peru]
# 1488                                [Cameroon, Nigeria]
# 1711                                            [Kenya]
# 1933               [Eswatini, South Africa, Mozambique]
# 503                                            [Mexico]
# 1155                                          [Bolivia]
# 914                                  [Papua New Guinea]
# 1684                                         [Colombia]
# 1181                        [Belize, Mexico, Guatemala]
# 437                                              [Peru]
# 2156                                                NaN
# 399                                  [Papua New Guinea]
# 1962                                                NaN

# %%
country_to_language = locations_df[locations_df.country.notnull()][['entity', 'country']
                                            ].drop_duplicates().country.value_counts().reset_index().rename(
columns={'country': 'number_of_languages', 'index': 'nation'})
country_to_language.to_csv('country-to-language-count.csv',
                                                                      index=False
                                                                     )
country_to_language
# Out:
#                                   nation  number_of_languages
# 0                       Papua New Guinea                  212
# 1                                 Mexico                  147
# 2                                  India                  117
# 3                              Indonesia                  100
# 4                            Philippines                   80
# ..                                   ...                  ...
# 293                       Czechoslovakia                    1
# 294           Kingdom of the Netherlands                    1
# 295                        New Caledonia                    1
# 296                   Dominican Republic                    1
# 297  Turkish Republic of Northern Cyprus                    1
#
# [298 rows x 2 columns]

# %%
country_to_language = locations_df[locations_df.country.notnull()][['entity', 'country']
                                            ].drop_duplicates().country.value_counts().reset_index().rename(
columns={'country': 'number_of_languages', 'index': 'nation'})
country_to_language.to_csv('country-to-language-count.csv',
                                                                      index=False
                                                                     )
country_to_language
# Out:
#                                   nation  number_of_languages
# 0                       Papua New Guinea                  212
# 1                                 Mexico                  147
# 2                                  India                  117
# 3                              Indonesia                  100
# 4                            Philippines                   80
# ..                                   ...                  ...
# 293                       Czechoslovakia                    1
# 294           Kingdom of the Netherlands                    1
# 295                        New Caledonia                    1
# 296                   Dominican Republic                    1
# 297  Turkish Republic of Northern Cyprus                    1
#
# [298 rows x 2 columns]

# %%
locations_df
# Out:
#      entity                     country indigenous_to_name  \
# 0     Q1860              American Samoa                NaN
# 1     Q1860                    Anguilla                NaN
# 2     Q1860         Antigua and Barbuda                NaN
# 3     Q1860                       Aruba                NaN
# 4     Q1860                   Australia                NaN
# ...     ...                         ...                ...
# 7834  Q9176                 South Korea                NaN
# 7835  Q9176                 North Korea                NaN
# 7836  Q9176  People's Republic of China                NaN
# 7837  Q9176                 North Korea        North Korea
# 7838  Q9176                 South Korea        South Korea
#
#      indigenous_to_entity  latitude  longitude location_entity location_name
# 0                     NaN       NaN        NaN             NaN           NaN
# 1                     NaN       NaN        NaN             NaN           NaN
# 2                     NaN       NaN        NaN             NaN           NaN
# 3                     NaN       NaN        NaN             NaN           NaN
# 4                     NaN       NaN        NaN             NaN           NaN
# ...                   ...       ...        ...             ...           ...
# 7834                  NaN       NaN        NaN             NaN           NaN
# 7835                  NaN       NaN        NaN             NaN           NaN
# 7836                  NaN       NaN        NaN             NaN           NaN
# 7837                 Q423       NaN        NaN             NaN           NaN
# 7838                 Q884       NaN        NaN             NaN           NaN
#
# [7839 rows x 8 columns]

# %%
locations_df.entity.nunique()
# Out:
# 1486

# %%
locations_df[locations_df.country.notnull()].country.value_counts().reset_index().rename(
columns={'country': 'number_of_languages', 'index': 'nation'}).to_csv('country-to-language-count.csv',
                                                                      index=False
                                                                     )

# %%
languages_without_countries = locations_df[~locations_df.entity.isin(languages_with_countries)]
languages_without_countries
# Out:
#       entity country   indigenous_to_name indigenous_to_entity  latitude  \
# 7116  Q35497     NaN  Mediterranean Basin               Q72499       NaN
#
#       longitude location_entity location_name
# 7116        NaN             NaN           NaN

# %%
def nullable(f):
    def wrapped(claim_list):
        if type(claim_list) == float:
            return numpy.nan
        else:
            return f(claim_list)
    return wrapped

# %%
@nullable
def make_label_list(claim_list):   return [get_label(x['value']['id']) for x in claim_list]

@nullable
def first_label(claim_list): return '' if len(claim_list) == 0 else get_label(claim_list[0]['value']['id'])

def emptiness(claim_list): return False if type(claim_list) == float or len(claim_list) == 0 else True

@nullable
def as_is(claim_list):  return [x['value'] for x in claim_list]

@nullable
def comma_list(claim_list): return ', '.join(make_label_list(claim_list))
    
def translator_func(claim):        
    if claim in ['P17', 'P276', 'P527', 'P2341',  'P279', 'P2283', 'P461', 'P460', 'P495',
                'P4913', 'P282', 'P4132', 'P737']: return make_label_list
    if claim in ['P5913', 'P2192', 'P5206', 'P2989', 'P5109', 'P5110', 'P3161', 'P3103']: return emptiness
    if claim in ['P1365', 'P1535','P144']: return first_label
    if claim in ['P625']: return coordinates
    if claim in ['P3823']: return comma_list
    return as_is

# %%
language_claim_records = []
for entity in version_codes.entity.unique():
    this_entity = {'entity': entity, 'name': get_label(entity) }
    for claim in useful_and_interesting_claims:
        f = translator_func(claim)
        this_entity[claim + "_" + get_property_label(claim)] = f(get_claim_list(entity, claim))
    language_claim_records.append(this_entity)
language_claim_df = pandas.DataFrame.from_records(language_claim_records).set_index('entity')

# %%
language_claim_df
# Out:
#                        name  P5913_has inflection class  \
# entity
# Q1860               English                       False
# Q5166             'Auhelawa                       False
# Q3073568               Abau                       False
# Q34835                 Abua                       False
# Q56657                 Abun                       False
# ...                     ...                         ...
# Q33375                Hakka                       False
# Q37041    Classical Chinese                       False
# Q5287              Japanese                       False
# Q7850               Chinese                       False
# Q9176                Korean                       False
#
#           P2192_endangeredlanguages.com ID       P1365_replaces  \
# entity
# Q1860                                False
# Q5166                                False
# Q3073568                              True
# Q34835                               False
# Q56657                                True
# ...                                    ...                  ...
# Q33375                               False       Middle Chinese
# Q37041                               False
# Q5287                                False
# Q7850                                False
# Q9176                                False  Early Modern Korean
#
#                                         P2341_indigenous to  \
# entity
# Q1860     [England, Scotland, United Kingdom, Wales, Ire...
# Q5166                                  [Milne Bay Province]
# Q3073568                                 [Sandaun Province]
# Q34835            [Federal Capital Territory, Rivers State]
# Q56657                                  [Papua, West Papua]
# ...                                                     ...
# Q33375    [Guangxi, Fujian, Guangdong, Hainan, Hunan, Ji...
# Q37041                                                   []
# Q5287                                               [Japan]
# Q7850                                                    []
# Q9176                            [North Korea, South Korea]
#
#          P3823_Ethnologue language status  P5206_has conjugation class  \
# entity
# Q1860                          1 National                        False
# Q5166                        5 Developing                        False
# Q3073568                     5 Developing                        False
# Q34835                        6a Vigorous                        False
# Q56657                      6b Threatened                        False
# ...                                   ...                          ...
# Q33375                       5 Developing                        False
# Q37041                                                           False
# Q5287                          1 National                        False
# Q7850                                                            False
# Q9176                          1 National                        False
#
#           P2989_has grammatical case  \
# entity
# Q1860                           True
# Q5166                          False
# Q3073568                       False
# Q34835                         False
# Q56657                         False
# ...                              ...
# Q33375                         False
# Q37041                         False
# Q5287                          False
# Q7850                          False
# Q9176                          False
#
#                                      P279_subclass of  \
# entity
# Q1860                              [Anglic languages]
# Q5166                        [Austronesian languages]
# Q3073568                            [Sepik languages]
# Q34835                      [Central Delta languages]
# Q56657                                             []
# ...                                               ...
# Q33375                   [Chinese, Sinitic languages]
# Q37041                     [written Chinese language]
# Q5287           [Japonic languages, language isolate]
# Q7850     [Sino-Tibetan languages, Sinitic languages]
# Q9176                            [Koreanic languages]
#
#           P5110_has grammatical person  ...  P460_said to be the same as  \
# entity                                  ...
# Q1860                             True  ...                   [Oldspeak]
# Q5166                            False  ...                           []
# Q3073568                         False  ...                           []
# Q34835                           False  ...                           []
# Q56657                           False  ...                           []
# ...                                ...  ...                          ...
# Q33375                           False  ...                           []
# Q37041                           False  ...                           []
# Q5287                            False  ...                           []
# Q7850                            False  ...   [Sinitic languages, Huáyǔ]
# Q9176                            False  ...                           []
#
#                                   P4132_linguistic typology  \
# entity
# Q1860     [subject–verb–object, nominative–accusative la...
# Q5166                                                    []
# Q3073568                                                 []
# Q34835                                                   []
# Q56657                                                   []
# ...                                                     ...
# Q33375                [subject–verb–object, tonal language]
# Q37041                                                   []
# Q5287     [subject–object–verb, nominative–accusative la...
# Q7850             [subject–verb–object, isolating language]
# Q9176         [subject–object–verb, agglutinative language]
#
#                                                  P2283_uses  \
# entity
# Q1860                                                    []
# Q5166                                                    []
# Q3073568                                                 []
# Q34835                                                   []
# Q56657                                                   []
# ...                                                     ...
# Q33375    [Hakka Chinese characters, Hakka Transliterati...
# Q37041                                                   []
# Q5287                                                    []
# Q7850                                                    []
# Q9176                                                    []
#
#          P3161_has grammatical mood  \
# entity
# Q1860                          True
# Q5166                         False
# Q3073568                      False
# Q34835                        False
# Q56657                        False
# ...                             ...
# Q33375                        False
# Q37041                        False
# Q5287                          True
# Q7850                         False
# Q9176                         False
#
#                                    P1098_number of speakers P1535_used by  \
# entity
# Q1860     [{'amount': '+339370920', 'unit': '1'}, {'amou...
# Q5166                    [{'amount': '+1200', 'unit': '1'}]
# Q3073568                 [{'amount': '+7270', 'unit': '1'}]
# Q34835                                                   []
# Q56657                   [{'amount': '+3000', 'unit': '1'}]
# ...                                                     ...           ...
# Q33375               [{'amount': '+30000000', 'unit': '1'}]
# Q37041                                                   []
# Q5287     [{'amount': '+130000000', 'unit': '1', 'upperB...
# Q7850              [{'amount': '+1299877520', 'unit': '1'}]
# Q9176                [{'amount': '+73233270', 'unit': '1'}]
#
#           P126_maintained by P1249_time of earliest written record  \
# entity
# Q1860                     []                                    []
# Q5166                     []                                    []
# Q3073568                  []                                    []
# Q34835                    []                                    []
# Q56657                    []                                    []
# ...                      ...                                   ...
# Q33375                    []                                    []
# Q37041                    []                                    []
# Q5287                     []                                    []
# Q7850                     []                                    []
# Q9176                     []                                    []
#
#          P144_based on                                 P737_influenced by
# entity
# Q1860                   [French, Vulgar Latin, Germanic languages, Greek]
# Q5166                                                                  []
# Q3073568                                                               []
# Q34835                                                                 []
# Q56657                                                                 []
# ...                ...                                                ...
# Q33375                                                                 []
# Q37041                                                                 []
# Q5287                                                                  []
# Q7850                                                                  []
# Q9176                                                                  []
#
# [1501 rows x 27 columns]

# %%
language_claim_df['P1098_number of speakers'].map(lambda x: [] if type(x) != list else [t['unit'] for t in x])
# Out:
# entity
# Q1860       [1, 1, 1, 1, 1]
# Q5166                   [1]
# Q3073568                [1]
# Q34835                   []
# Q56657                  [1]
#                  ...
# Q33375                  [1]
# Q37041                   []
# Q5287                   [1]
# Q7850                   [1]
# Q9176                   [1]
# Name: P1098_number of speakers, Length: 1501, dtype: object

# %%
language_claim_df['P1098_number of speakers'].map(lambda x: [] if type(x) != list else [t.keys() for t in x])
# Out:
# entity
# Q1860       [(amount, unit), (amount, unit), (amount, unit...
# Q5166                                        [(amount, unit)]
# Q3073568                                     [(amount, unit)]
# Q34835                                                     []
# Q56657                                       [(amount, unit)]
#                                   ...
# Q33375                                       [(amount, unit)]
# Q37041                                                     []
# Q5287                [(amount, unit, upperBound, lowerBound)]
# Q7850                                        [(amount, unit)]
# Q9176                                        [(amount, unit)]
# Name: P1098_number of speakers, Length: 1501, dtype: object

# %%
language_claim_df['P1098_number of speakers'].loc['Q1860']
# Out:
# [{'amount': '+339370920', 'unit': '1'},
#  {'amount': '+603163010', 'unit': '1'},
#  {'amount': '+379007140', 'unit': '1'},
#  {'amount': '+753359540', 'unit': '1'},
#  {'amount': '+1132366680', 'unit': '1'}]

# %%
version_codes[version_codes.language.isin(['hak', 'jpn', 'lzh', 'nob', 'qvz', 'zho', 'zho_tw', 'tha'])]
# Out:
#       version_id language                                       version_name  \
# 1257        1372      nob     bibelen guds ord hverdagsbibelen hermon forlag
# 1258        1373      nob                                bibelen 2011 bokmal
# 1259        1374      nob                              bibelen guds ord 2017
# 1260        1375      nob                        det norsk bibelselskap 1930
# 1261        1376      nob                                     en levende bok
# 1262        1377      nob                             norsk bibel 88slash 07
# 1263        1378      nob         the bible in norwegian 1978slash 85 bokmal
# 1280        1396      qvz                                       diospa shimi
# 2097        2290      tha                                               1940
# 2098        2291      tha                                               erv
# 2099        2292      tha                                                NaN
# 2100        2293      tha                                                ntv
# 2101        2294      tha                                                kjv
# 2102        2295      tha                                               1971
# 2120        2313      hak  %E5%AE%A2%E8%AA%9E%E8%81%96%E7%B6%93 %E7%8F%BE...
# 2121        2314      lzh                             griffith john wenli nt
# 2122        2315      lzh  %E4%BF%84%E7%BE%85%E6%96%AF%E6%AD%A3%E6%95%99%...
# 2123        2316      lzh  %E5%8C%85%E7%88%BE%E9%A8%B0%E6%9F%8F%E6%BC%A2%...
# 2124        2317      lzh  %E6%96%87%E7%90%86%E5%A7%94%E8%BE%A6%E8%AD%AF%...
# 2125        2318      lzh  %E6%96%87%E7%90%86%E5%92%8C%E5%90%88%E8%AD%AF%...
# 2126        2319      lzh  %E6%96%BD%E7%B4%84%E7%91%9F%E6%B7%BA%E6%96%87%...
# 2127        2321      lzh  %E6%B7%BA%E6%96%87%E7%90%86%E5%92%8C%E5%90%88%...
# 2128        2322      lzh  %E6%B9%9B%E7%B4%84%E7%BF%B0%E9%9F%B6%E7%91%AA%...
# 2129        2323      lzh  %E7%99%BD%E6%97%A5%E6%98%87%E5%BE%90%E7%B4%84%...
# 2130        2324      lzh  %E8%A3%A8%E6%B2%BB%E6%96%87%E5%85%8B%E9%99%9B%...
# 2131        2325      lzh  %E9%A6%AC%E6%AE%8A%E6%9B%BC%E6%8B%89%E6%92%92%...
# 2132        2326      lzh  %E9%A6%AC%E7%A6%AE%E9%81%9C%E7%B1%B3%E6%86%90%...
# 2133        2327      jpn         alive %E6%96%B0%E7%B4%84%E8%81%96%E6%9B%B8
# 2134        2328      jpn                           colloquial japanese 1955
# 2135        2329      jpn  japanese %E8%81%96%E6%9B%B8 %E5%8F%A3%E8%AA%9E...
# 2136        2330      jpn  seisho shinkyoudoyaku %E8%81%96%E6%9B%B8 %E6%9...
# 2137        2331      zho  %E4%B8%AD%E6%96%87%E6%A0%87%E5%87%86%E8%AF%91%...
# 2138        2332      zho  %E5%92%8C%E5%90%88%E6%9C%AC%E4%BF%AE%E8%AE%A2%...
# 2139        2333      zho  %E5%9C%A3%E7%BB%8F%E5%BD%93%E4%BB%A3%E8%AF%91%...
# 2140        2334      zho  %E4%B8%8A%E5%B8%9D %E6%96%B0%E6%A0%87%E7%82%B9...
# 2141        2336      zho                        %E6%96%B0%E8%AF%91%E6%9C%AC
# 2142        2337   zho_tw  %E5%AE%98%E8%A9%B1%E5%92%8C%E5%90%88%E8%AD%AF%...
# 2143        2338   zho_tw  %E4%B8%AD%E6%96%87%E6%A8%99%E6%BA%96%E8%AD%AF%...
# 2144        2339   zho_tw  %E5%8C%97%E4%BA%AC%E5%AE%98%E8%A9%B1%E8%AD%AF%...
# 2145        2340   zho_tw  %E5%8D%97%E4%BA%AC%E5%AE%98%E8%A9%B1%E6%96%B0%...
# 2146        2341   zho_tw  %E7%A5%9E%E7%89%88 %E5%92%8C%E5%90%88%E6%9C%AC...
# 2147        2342   zho_tw  %E5%92%8C%E5%90%88%E6%9C%AC%E4%BF%AE%E8%A8%82%...
# 2148        2343   zho_tw  %E5%9B%9B%E7%A6%8F%E9%9F%B3%E6%9B%B8 %E5%85%B1...
# 2149        2344   zho_tw  %E4%B8%8A%E5%B8%9D %E6%96%B0%E6%A8%99%E9%BB%9E...
# 2150        2345   zho_tw  %E7%A5%9E %E6%96%B0%E6%A8%99%E9%BB%9E%E5%92%8C...
# 2151        2346   zho_tw                        %E6%96%B0%E8%AD%AF%E6%9C%AC
# 2152        2347   zho_tw  %E6%9C%B1%E5%AF%B6%E6%83%A0%E9%87%8D%E8%AD%AF%...
# 2153        2348   zho_tw  %E6%9D%8E%E5%B1%B1%E7%94%AB%E7%AD%89%E6%96%B0%...
# 2154        2349   zho_tw  %E6%A5%8A%E6%A0%BC%E9%9D%9E%E5%AE%98%E8%A9%B1%...
# 2155        2351   zho_tw  %E7%8E%8B%E5%85%83%E5%BE%B7%E6%96%B0%E5%BC%8F%...
# 2156        2352   zho_tw  %E8%81%96%E7%B6%93%E7%95%B6%E4%BB%A3%E8%AD%AF%...
# 2157        2353   zho_tw  %E8%95%AD%E9%90%B5%E7%AC%9B%E6%96%B0%E8%AD%AF%...
# 2158        2354   zho_tw  %E8%95%AD%E9%9D%9C%E5%B1%B1%E6%96%B0%E7%B6%93%...
# 2159        2355   zho_tw  %E9%99%B8%E4%BA%A8%E7%90%86%E9%84%AD%E5%A3%BD%...
# 2161        2335      zho  %E7%A5%9E %E6%96%B0%E6%A0%87%E7%82%B9%E5%92%8C...
#
#                                wikidata_entity     entity  \
# 1257     http://www.wikidata.org/entity/Q25167     Q25167
# 1258     http://www.wikidata.org/entity/Q25167     Q25167
# 1259     http://www.wikidata.org/entity/Q25167     Q25167
# 1260     http://www.wikidata.org/entity/Q25167     Q25167
# 1261     http://www.wikidata.org/entity/Q25167     Q25167
# 1262     http://www.wikidata.org/entity/Q25167     Q25167
# 1263     http://www.wikidata.org/entity/Q25167     Q25167
# 1280  http://www.wikidata.org/entity/Q12953848  Q12953848
# 2097      http://www.wikidata.org/entity/Q9217      Q9217
# 2098      http://www.wikidata.org/entity/Q9217      Q9217
# 2099      http://www.wikidata.org/entity/Q9217      Q9217
# 2100      http://www.wikidata.org/entity/Q9217      Q9217
# 2101      http://www.wikidata.org/entity/Q9217      Q9217
# 2102      http://www.wikidata.org/entity/Q9217      Q9217
# 2120     http://www.wikidata.org/entity/Q33375     Q33375
# 2121     http://www.wikidata.org/entity/Q37041     Q37041
# 2122     http://www.wikidata.org/entity/Q37041     Q37041
# 2123     http://www.wikidata.org/entity/Q37041     Q37041
# 2124     http://www.wikidata.org/entity/Q37041     Q37041
# 2125     http://www.wikidata.org/entity/Q37041     Q37041
# 2126     http://www.wikidata.org/entity/Q37041     Q37041
# 2127     http://www.wikidata.org/entity/Q37041     Q37041
# 2128     http://www.wikidata.org/entity/Q37041     Q37041
# 2129     http://www.wikidata.org/entity/Q37041     Q37041
# 2130     http://www.wikidata.org/entity/Q37041     Q37041
# 2131     http://www.wikidata.org/entity/Q37041     Q37041
# 2132     http://www.wikidata.org/entity/Q37041     Q37041
# 2133      http://www.wikidata.org/entity/Q5287      Q5287
# 2134      http://www.wikidata.org/entity/Q5287      Q5287
# 2135      http://www.wikidata.org/entity/Q5287      Q5287
# 2136      http://www.wikidata.org/entity/Q5287      Q5287
# 2137      http://www.wikidata.org/entity/Q7850      Q7850
# 2138      http://www.wikidata.org/entity/Q7850      Q7850
# 2139      http://www.wikidata.org/entity/Q7850      Q7850
# 2140      http://www.wikidata.org/entity/Q7850      Q7850
# 2141      http://www.wikidata.org/entity/Q7850      Q7850
# 2142                                       NaN        NaN
# 2143                                       NaN        NaN
# 2144                                       NaN        NaN
# 2145                                       NaN        NaN
# 2146                                       NaN        NaN
# 2147                                       NaN        NaN
# 2148                                       NaN        NaN
# 2149                                       NaN        NaN
# 2150                                       NaN        NaN
# 2151                                       NaN        NaN
# 2152                                       NaN        NaN
# 2153                                       NaN        NaN
# 2154                                       NaN        NaN
# 2155                                       NaN        NaN
# 2156                                       NaN        NaN
# 2157                                       NaN        NaN
# 2158                                       NaN        NaN
# 2159                                       NaN        NaN
# 2161      http://www.wikidata.org/entity/Q7850      Q7850
#
#       language_name_in_english  \
# 1257                    Bokmål
# 1258                    Bokmål
# 1259                    Bokmål
# 1260                    Bokmål
# 1261                    Bokmål
# 1262                    Bokmål
# 1263                    Bokmål
# 1280  Northern Pastaza Quichua
# 2097                      Thai
# 2098                      Thai
# 2099                      Thai
# 2100                      Thai
# 2101                      Thai
# 2102                      Thai
# 2120                     Hakka
# 2121         Classical Chinese
# 2122         Classical Chinese
# 2123         Classical Chinese
# 2124         Classical Chinese
# 2125         Classical Chinese
# 2126         Classical Chinese
# 2127         Classical Chinese
# 2128         Classical Chinese
# 2129         Classical Chinese
# 2130         Classical Chinese
# 2131         Classical Chinese
# 2132         Classical Chinese
# 2133                  Japanese
# 2134                  Japanese
# 2135                  Japanese
# 2136                  Japanese
# 2137                   Chinese
# 2138                   Chinese
# 2139                   Chinese
# 2140                   Chinese
# 2141                   Chinese
# 2142                       NaN
# 2143                       NaN
# 2144                       NaN
# 2145                       NaN
# 2146                       NaN
# 2147                       NaN
# 2148                       NaN
# 2149                       NaN
# 2150                       NaN
# 2151                       NaN
# 2152                       NaN
# 2153                       NaN
# 2154                       NaN
# 2155                       NaN
# 2156                       NaN
# 2157                       NaN
# 2158                       NaN
# 2159                       NaN
# 2161                   Chinese
#
#                                             instance_of  \
# 1257  [language, standard language, written language...
# 1258  [language, standard language, written language...
# 1259  [language, standard language, written language...
# 1260  [language, standard language, written language...
# 1261  [language, standard language, written language...
# 1262  [language, standard language, written language...
# 1263  [language, standard language, written language...
# 1280  [language, modern language, definitely endange...
# 2097      [natural language, modern language, language]
# 2098      [natural language, modern language, language]
# 2099      [natural language, modern language, language]
# 2100      [natural language, modern language, language]
# 2101      [natural language, modern language, language]
# 2102      [natural language, modern language, language]
# 2120                        [language, modern language]
# 2121            [written language, historical language]
# 2122            [written language, historical language]
# 2123            [written language, historical language]
# 2124            [written language, historical language]
# 2125            [written language, historical language]
# 2126            [written language, historical language]
# 2127            [written language, historical language]
# 2128            [written language, historical language]
# 2129            [written language, historical language]
# 2130            [written language, historical language]
# 2131            [written language, historical language]
# 2132            [written language, historical language]
# 2133                        [language, modern language]
# 2134                        [language, modern language]
# 2135                        [language, modern language]
# 2136                        [language, modern language]
# 2137  [language family, macrolanguage, modern langua...
# 2138  [language family, macrolanguage, modern langua...
# 2139  [language family, macrolanguage, modern langua...
# 2140  [language family, macrolanguage, modern langua...
# 2141  [language family, macrolanguage, modern langua...
# 2142                                                NaN
# 2143                                                NaN
# 2144                                                NaN
# 2145                                                NaN
# 2146                                                NaN
# 2147                                                NaN
# 2148                                                NaN
# 2149                                                NaN
# 2150                                                NaN
# 2151                                                NaN
# 2152                                                NaN
# 2153                                                NaN
# 2154                                                NaN
# 2155                                                NaN
# 2156                                                NaN
# 2157                                                NaN
# 2158                                                NaN
# 2159                                                NaN
# 2161  [language family, macrolanguage, modern langua...
#
#                                                 country
# 1257                                           [Norway]
# 1258                                           [Norway]
# 1259                                           [Norway]
# 1260                                           [Norway]
# 1261                                           [Norway]
# 1262                                           [Norway]
# 1263                                           [Norway]
# 1280                                    [Ecuador, Peru]
# 2097                               [Cambodia, Thailand]
# 2098                               [Cambodia, Thailand]
# 2099                               [Cambodia, Thailand]
# 2100                               [Cambodia, Thailand]
# 2101                               [Cambodia, Thailand]
# 2102                               [Cambodia, Thailand]
# 2120  [Indonesia, Brunei, People's Republic of China...
# 2121                                                NaN
# 2122                                                NaN
# 2123                                                NaN
# 2124                                                NaN
# 2125                                                NaN
# 2126                                                NaN
# 2127                                                NaN
# 2128                                                NaN
# 2129                                                NaN
# 2130                                                NaN
# 2131                                                NaN
# 2132                                                NaN
# 2133  [Japan, United States of America, Taiwan, Nort...
# 2134  [Japan, United States of America, Taiwan, Nort...
# 2135  [Japan, United States of America, Taiwan, Nort...
# 2136  [Japan, United States of America, Taiwan, Nort...
# 2137                       [People's Republic of China]
# 2138                       [People's Republic of China]
# 2139                       [People's Republic of China]
# 2140                       [People's Republic of China]
# 2141                       [People's Republic of China]
# 2142                                                NaN
# 2143                                                NaN
# 2144                                                NaN
# 2145                                                NaN
# 2146                                                NaN
# 2147                                                NaN
# 2148                                                NaN
# 2149                                                NaN
# 2150                                                NaN
# 2151                                                NaN
# 2152                                                NaN
# 2153                                                NaN
# 2154                                                NaN
# 2155                                                NaN
# 2156                                                NaN
# 2157                                                NaN
# 2158                                                NaN
# 2159                                                NaN
# 2161                       [People's Republic of China]

# %%
version_codes[version_codes.language_name_in_english.isin(['Bahasa', 'Indonesian', 'Malay', 'Russian', 'Esperanto'])]
# Out:
#       version_id language                                       version_name  \
# 175          197      ind                            alkitab terjemahan baru
# 176          198      ind                         tl alkitab terjemahan lama
# 177          199      ind           alkitab dalam bahasa indonesia masa kini
# 178          200      ind                            firman allah yang hidup
# 179          201      ind                     indonesian tazi nt study bible
# 180          202      ind            perjanjian baru terjemahan baru edisi 2
# 181          203      ind                 perjanjian baru versi mudah dibaca
# 182          204      ind                     terjemahan sederhana indonesia
# 183          205      msa                                alkitab berita baik
# 184          206      msa                alkitab berita baik deuterokanonika
# 185          207      msa                               alkitab versi borneo
# 186          208      msa     kitab alkudus injil isa almasih 1866 keasberry
# 502          553      epo     la sankta biblio 1926 esperanto londona biblio
# 1979        2160      rus  t central asian russian scriptures cars tajiki...
# 1980        2161      rus              bibliya na cerkovnoslavyanskom yazyke
# 1981        2162      rus  bibliya pod red m dot p kulakova i m dot m kul...
# 1982        2163      rus                                 vostochnyj perevod
# 1983        2164      rus             a vostochnyj perevod versiya s allahom
# 1984        2165      rus                              novyj russkij perevod
# 1985        2166      rus               svyataya bibliya sovremennyj perevod
# 1986        2167      rus                                 sinodalnyj perevod
# 1987        2168      rus                                 sinodalnyj perevod
# 1988        2169      rus         2 sovremennyj russkij perevod 2 e izd dot
# 1989        2170      rus                                perevod ep kassiana
#
#                            wikidata_entity entity language_name_in_english  \
# 175   http://www.wikidata.org/entity/Q9240  Q9240               Indonesian
# 176   http://www.wikidata.org/entity/Q9240  Q9240               Indonesian
# 177   http://www.wikidata.org/entity/Q9240  Q9240               Indonesian
# 178   http://www.wikidata.org/entity/Q9240  Q9240               Indonesian
# 179   http://www.wikidata.org/entity/Q9240  Q9240               Indonesian
# 180   http://www.wikidata.org/entity/Q9240  Q9240               Indonesian
# 181   http://www.wikidata.org/entity/Q9240  Q9240               Indonesian
# 182   http://www.wikidata.org/entity/Q9240  Q9240               Indonesian
# 183   http://www.wikidata.org/entity/Q9237  Q9237                    Malay
# 184   http://www.wikidata.org/entity/Q9237  Q9237                    Malay
# 185   http://www.wikidata.org/entity/Q9237  Q9237                    Malay
# 186   http://www.wikidata.org/entity/Q9237  Q9237                    Malay
# 502    http://www.wikidata.org/entity/Q143   Q143                Esperanto
# 1979  http://www.wikidata.org/entity/Q7737  Q7737                  Russian
# 1980  http://www.wikidata.org/entity/Q7737  Q7737                  Russian
# 1981  http://www.wikidata.org/entity/Q7737  Q7737                  Russian
# 1982  http://www.wikidata.org/entity/Q7737  Q7737                  Russian
# 1983  http://www.wikidata.org/entity/Q7737  Q7737                  Russian
# 1984  http://www.wikidata.org/entity/Q7737  Q7737                  Russian
# 1985  http://www.wikidata.org/entity/Q7737  Q7737                  Russian
# 1986  http://www.wikidata.org/entity/Q7737  Q7737                  Russian
# 1987  http://www.wikidata.org/entity/Q7737  Q7737                  Russian
# 1988  http://www.wikidata.org/entity/Q7737  Q7737                  Russian
# 1989  http://www.wikidata.org/entity/Q7737  Q7737                  Russian
#
#                                             instance_of  \
# 175      [language, standard language, modern language]
# 176      [language, standard language, modern language]
# 177      [language, standard language, modern language]
# 178      [language, standard language, modern language]
# 179      [language, standard language, modern language]
# 180      [language, standard language, modern language]
# 181      [language, standard language, modern language]
# 182      [language, standard language, modern language]
# 183          [language, macrolanguage, modern language]
# 184          [language, macrolanguage, modern language]
# 185          [language, macrolanguage, modern language]
# 186          [language, macrolanguage, modern language]
# 502   [planned language, international auxiliary lan...
# 1979      [modern language, language, natural language]
# 1980      [modern language, language, natural language]
# 1981      [modern language, language, natural language]
# 1982      [modern language, language, natural language]
# 1983      [modern language, language, natural language]
# 1984      [modern language, language, natural language]
# 1985      [modern language, language, natural language]
# 1986      [modern language, language, natural language]
# 1987      [modern language, language, natural language]
# 1988      [modern language, language, natural language]
# 1989      [modern language, language, natural language]
#
#                                                 country
# 175                                         [Indonesia]
# 176                                         [Indonesia]
# 177                                         [Indonesia]
# 178                                         [Indonesia]
# 179                                         [Indonesia]
# 180                                         [Indonesia]
# 181                                         [Indonesia]
# 182                                         [Indonesia]
# 183   [Malaysia, Indonesia, Brunei, Singapore, East ...
# 184   [Malaysia, Indonesia, Brunei, Singapore, East ...
# 185   [Malaysia, Indonesia, Brunei, Singapore, East ...
# 186   [Malaysia, Indonesia, Brunei, Singapore, East ...
# 502                            [Russian Empire, Poland]
# 1979  [Russia, Germany, Kazakhstan, Israel, Mongolia...
# 1980  [Russia, Germany, Kazakhstan, Israel, Mongolia...
# 1981  [Russia, Germany, Kazakhstan, Israel, Mongolia...
# 1982  [Russia, Germany, Kazakhstan, Israel, Mongolia...
# 1983  [Russia, Germany, Kazakhstan, Israel, Mongolia...
# 1984  [Russia, Germany, Kazakhstan, Israel, Mongolia...
# 1985  [Russia, Germany, Kazakhstan, Israel, Mongolia...
# 1986  [Russia, Germany, Kazakhstan, Israel, Mongolia...
# 1987  [Russia, Germany, Kazakhstan, Israel, Mongolia...
# 1988  [Russia, Germany, Kazakhstan, Israel, Mongolia...
# 1989  [Russia, Germany, Kazakhstan, Israel, Mongolia...
